# %% [markdown]
# # 🧩 Simulating Distributions – Visualization & Summary Stats

# %%
# Setup and Imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import sys

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Imports
from utils.visual_utils import plot_multiple_distributions
from utils.model_utils import summarize_simulated_distributions

# %%
# 📁 Paths
EXPORT_PLOTS = Path("../exports/plots/common_distribution_simulation")
EXPORT_TABLES = Path("../exports/tables/common_distribution_simulation")
EXPORT_PLOTS.mkdir(parents=True, exist_ok=True)
EXPORT_TABLES.mkdir(parents=True, exist_ok=True)

# %%
# 🎲 Simulate 4 Different Distributions
np.random.seed(42)
dist_data = {
    "Normal (μ=0, σ=1)": np.random.normal(loc=0, scale=1, size=1000),
    "Skewed (Exponential)": np.random.exponential(scale=1.0, size=1000),
    "Uniform (0, 1)": np.random.uniform(0, 1, size=1000),
    "Bimodal (2 Normals)": np.concatenate([np.random.normal(-2, 0.5, 500),
                                           np.random.normal(2, 0.5, 500)])
}

# %%
# 📈 Plot All Distributions
plot_multiple_distributions(dist_data, bins=30)

# %%
# 📊 Summarize Distribution Properties
summary_df = summarize_simulated_distributions(dist_data)
display(summary_df)
summary_df.to_csv(EXPORT_TABLES / "distribution_summary.csv", index=False)
# Out:
#            Distribution      Mean       Std  Skewness  Kurtosis
# 0     Normal (μ=0, σ=1)  0.019332  0.978726  0.116801  0.066206
# 1  Skewed (Exponential)  1.007986  1.002487  1.980812  5.379440
# 2        Uniform (0, 1)  0.494495  0.288775  0.009551 -1.180411
# 3   Bimodal (2 Normals)  0.003644  2.073199  0.011070 -1.763235

# %% [markdown]
# ## ✅ Summary:
# - Simulated 4 common distributions: Normal, Exponential, Uniform, and Bimodal
# - Visualized each using KDE-augmented histograms
# - Compared summary statistics including mean, std, skewness, and kurtosis
# - Exported the summary table for reproducibility
